# %%
import pandas as pd

# %% [markdown]
# # read the data and inspect it

# %%
pwd
# Out:
# '/home/micha/Data_Science/Ulmer_Verein/Survey_working_conditions_art_history/notebooks'

# %%
raw_data = pd.read_excel('../data/external/Umfrage_kompletter Datensatz.xlsx')

# %%
raw_data.head()
# Out:
#    id. Antwort ID submitdate. Datum Abgeschickt  lastpage. Letzte Seite  \
# 0             953           1980-01-01 00:00:00                       8
# 1              24           1980-01-01 00:00:00                       8
# 2              57           1980-01-01 00:00:00                       8
# 3              65           1980-01-01 00:00:00                       8
# 4              93           1980-01-01 00:00:00                       8
#
#   startlanguage. Start-Sprache  seed. Zufallsgeneratorstartwert  \
# 0                           de                        396323143
# 1                           de                        663729984
# 2                           de                       1802233334
# 3                           de                       1672017186
# 4                           de                       1032237335
#
#   AP1. Wie alt sind Sie?  \
# 0                  30–34
# 1                  30–34
# 2                  40–44
# 3                  30–34
# ...

# %%
raw_data.columns
# Out:
# Index(['id. Antwort ID', 'submitdate. Datum Abgeschickt',
#        'lastpage. Letzte Seite', 'startlanguage. Start-Sprache',
#        'seed. Zufallsgeneratorstartwert', 'AP1. Wie alt sind Sie?',
#        'AP2[SQ001]. Welchen akademischen Grad haben Sie als letztes in welchem Jahr erworben?    [Bachelor of Arts: ]',
#        'AP2[SQ001comment]. Welchen akademischen Grad haben Sie als letztes in welchem Jahr erworben?    [Bachelor of Arts: ][Kommentar]',
#        'AP2[SQ002]. Welchen akademischen Grad haben Sie als letztes in welchem Jahr erworben?    [Master of Arts:]',
#        'AP2[SQ002comment]. Welchen akademischen Grad haben Sie als letztes in welchem Jahr erworben?    [Master of Arts:][Kommentar]',
#        ...
#        'CO13[SQ009]. Welche Auswirkungen sehen Sie durch die fortgeschrittene Digitalisierung auf Ihre Arbeit? [Normierung und Kanonisierung von Inhalten durch digitale Formate (z.B. Einführungskurse, Online-Führungen)]',
# ...

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1017 entries, 0 to 1016
# Columns: 690 entries, id. Antwort ID to CO15. Haben Sie Anmerkungen oder Anregungen zu diesem Fragebogen und seinem Thema? Bitte schreiben Sie uns auch, wenn Sie eine Formulierung oder Frage als diskriminierend empfanden.
# dtypes: float64(64), int64(3), object(623)
# memory usage: 5.4+ MB

# %%
raw_data.describe()
# Out:
#        id. Antwort ID  lastpage. Letzte Seite  \
# count     1017.000000                  1017.0
# mean       871.417896                     8.0
# std        502.363433                     0.0
# min          5.000000                     8.0
# 25%        441.000000                     8.0
# 50%        872.000000                     8.0
# 75%       1301.000000                     8.0
# max       1734.000000                     8.0
#
#        seed. Zufallsgeneratorstartwert  \
# count                     1.017000e+03
# mean                      1.044287e+09
# std                       6.032091e+08
# min                       1.823819e+06
# 25%                       5.164948e+08
# 50%                       1.030508e+09
# 75%                       1.535038e+09
# max                       2.145644e+09
#
#        AP2[SQ005comment]. Welchen akademischen Grad haben Sie als letztes in welchem Jahr erworben?    [II. Staatsexamen:][Kommentar]  \
# ...

# %% [markdown]
# # clean the data

# %%
# drop all columns that contain the string Kommentar
clean_data = raw_data.drop(raw_data.filter(regex='Kommentar').columns, axis=1)

# %%
clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1017 entries, 0 to 1016
# Columns: 658 entries, id. Antwort ID to CO15. Haben Sie Anmerkungen oder Anregungen zu diesem Fragebogen und seinem Thema? Bitte schreiben Sie uns auch, wenn Sie eine Formulierung oder Frage als diskriminierend empfanden.
# dtypes: float64(57), int64(3), object(598)
# memory usage: 5.1+ MB

# %%
clean_data.head()
# Out:
#    id. Antwort ID submitdate. Datum Abgeschickt  lastpage. Letzte Seite  \
# 0             953           1980-01-01 00:00:00                       8
# 1              24           1980-01-01 00:00:00                       8
# 2              57           1980-01-01 00:00:00                       8
# 3              65           1980-01-01 00:00:00                       8
# 4              93           1980-01-01 00:00:00                       8
#
#   startlanguage. Start-Sprache  seed. Zufallsgeneratorstartwert  \
# 0                           de                        396323143
# 1                           de                        663729984
# 2                           de                       1802233334
# 3                           de                       1672017186
# 4                           de                       1032237335
#
#   AP1. Wie alt sind Sie?  \
# 0                  30–34
# 1                  30–34
# 2                  40–44
# 3                  30–34
# ...

# %%
# replace all Ja with 1 and all Nein with 0
replacement_dict = {'Ja' : 1, 'Nein' : 0}
clean_data = clean_data.replace(replacement_dict)

# %%
clean_data.head()
# Out:
#    id. Antwort ID submitdate. Datum Abgeschickt  lastpage. Letzte Seite  \
# 0             953           1980-01-01 00:00:00                       8
# 1              24           1980-01-01 00:00:00                       8
# 2              57           1980-01-01 00:00:00                       8
# 3              65           1980-01-01 00:00:00                       8
# 4              93           1980-01-01 00:00:00                       8
#
#   startlanguage. Start-Sprache  seed. Zufallsgeneratorstartwert  \
# 0                           de                        396323143
# 1                           de                        663729984
# 2                           de                       1802233334
# 3                           de                       1672017186
# 4                           de                       1032237335
#
#   AP1. Wie alt sind Sie?  \
# 0                  30–34
# 1                  30–34
# 2                  40–44
# 3                  30–34
# ...

# %%
# drop all columns that exclusively contain NaN
print(len(clean_data.columns[clean_data.isna().all()]))
clean_data = clean_data.drop(clean_data.columns[clean_data.isna().all()], axis=1)
# Out:
# 14

# %%
clean_data.head()
# Out:
#    id. Antwort ID submitdate. Datum Abgeschickt  lastpage. Letzte Seite  \
# 0             953           1980-01-01 00:00:00                       8
# 1              24           1980-01-01 00:00:00                       8
# 2              57           1980-01-01 00:00:00                       8
# 3              65           1980-01-01 00:00:00                       8
# 4              93           1980-01-01 00:00:00                       8
#
#   startlanguage. Start-Sprache  seed. Zufallsgeneratorstartwert  \
# 0                           de                        396323143
# 1                           de                        663729984
# 2                           de                       1802233334
# 3                           de                       1672017186
# 4                           de                       1032237335
#
#   AP1. Wie alt sind Sie?  \
# 0                  30–34
# 1                  30–34
# 2                  40–44
# 3                  30–34
# ...

# %%
clean_data.dtypes
# Out:
# id. Antwort ID                                                                                                                                                                            int64
# submitdate. Datum Abgeschickt                                                                                                                                                            object
# lastpage. Letzte Seite                                                                                                                                                                    int64
# startlanguage. Start-Sprache                                                                                                                                                             object
# seed. Zufallsgeneratorstartwert                                                                                                                                                           int64
# ...

# %% [markdown]
# ## work on the object columns

# %%
object_columns = clean_data.select_dtypes(include='object')

# %%
object_columns.head()
# Out:
#   submitdate. Datum Abgeschickt startlanguage. Start-Sprache  \
# 0           1980-01-01 00:00:00                           de
# 1           1980-01-01 00:00:00                           de
# 2           1980-01-01 00:00:00                           de
# 3           1980-01-01 00:00:00                           de
# 4           1980-01-01 00:00:00                           de
#
#   AP1. Wie alt sind Sie? AP9. Haben Sie ein Volontariat gemacht?   \
# 0                  30–34                                Sonstiges
# 1                  30–34                                Sonstiges
# 2                  40–44                                        1
# 3                  30–34                                        0
# 4                  30–34                                Sonstiges
#
#   AP9[other]. Haben Sie ein Volontariat gemacht?  [Sonstiges]  \
# 0  Ich absolviere derzeit ein wissenschaftliches ...
# 1                               bin jetzt Volontärin
# ...

# %%
object_columns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1017 entries, 0 to 1016
# Columns: 168 entries, submitdate. Datum Abgeschickt to CO15. Haben Sie Anmerkungen oder Anregungen zu diesem Fragebogen und seinem Thema? Bitte schreiben Sie uns auch, wenn Sie eine Formulierung oder Frage als diskriminierend empfanden.
# dtypes: object(168)
# memory usage: 1.3+ MB

# %%
len(object_columns.filter(regex='Sonstiges').columns)
# Out:
# 74

# %%
object_columns.filter(regex='Sonstiges')
# Out:
#      AP9[other]. Haben Sie ein Volontariat gemacht?  [Sonstiges]  \
# 0     Ich absolviere derzeit ein wissenschaftliches ...
# 1                                  bin jetzt Volontärin
# 2                                                   NaN
# 3                                                   NaN
# 4                             Werde jetzt eins beginnen
# ...                                                 ...
# 1012                                                NaN
# 1013                                                NaN
# 1014                                                NaN
# 1015                                                NaN
# 1016                                                NaN
#
#      AP13r[other]. Wenn ja, in welcher Vereinigung:  [Sonstiges]  \
# 0                                                   NaN
# 1                                                   DMB
# 2                                                   NaN
# ...

# %%
object_columns = object_columns.drop(object_columns.filter(regex='Sonstiges'), axis=1)

# %%
object_columns.head()
# Out:
#   submitdate. Datum Abgeschickt startlanguage. Start-Sprache  \
# 0           1980-01-01 00:00:00                           de
# 1           1980-01-01 00:00:00                           de
# 2           1980-01-01 00:00:00                           de
# 3           1980-01-01 00:00:00                           de
# 4           1980-01-01 00:00:00                           de
#
#   AP1. Wie alt sind Sie? AP9. Haben Sie ein Volontariat gemacht?   \
# 0                  30–34                                Sonstiges
# 1                  30–34                                Sonstiges
# 2                  40–44                                        1
# 3                  30–34                                        0
# 4                  30–34                                Sonstiges
#
#   AP12. Engagieren Sie sich ehrenamtlich im kunstwissenschaftlichen Bereich?   \
# 0                                                  0
# 1                                                  0
# ...

# %%
object_columns = object_columns.drop(object_columns[['submitdate. Datum Abgeschickt', 'startlanguage. Start-Sprache']], axis=1)

# %%
object_columns.head()
# Out:
#   AP1. Wie alt sind Sie? AP9. Haben Sie ein Volontariat gemacht?   \
# 0                  30–34                                Sonstiges
# 1                  30–34                                Sonstiges
# 2                  40–44                                        1
# 3                  30–34                                        0
# 4                  30–34                                Sonstiges
#
#   AP12. Engagieren Sie sich ehrenamtlich im kunstwissenschaftlichen Bereich?   \
# 0                                                  0
# 1                                                  0
# 2                           Ja, in der Vergangenheit
# 3                                                  0
# 4                                                  1
#
# ...

# %%
object_columns['AP1. Wie alt sind Sie?'].unique()
# Out:
# array(['30–34', '40–44', 'Älter als 70', 'Unter 25', '25–29', '35–39',
#        '50–54', '60–64', '55–59', '45–49', '65–70', nan], dtype=object)

# %%
replacement_dict_Alter = {'Unter 25' : 0, 
                          '25–29' : 1, 
                          '30–34' : 2, 
                          '35–39' : 3, 
                          '40–44' : 4, 
                          '45–49' : 5,
                          '50–54' : 6,
                          '55–59' : 7,
                          '60–64' : 8,
                          '65–70' : 9,
                          'Älter als 70' : 10
                          }

object_columns['AP1. Wie alt sind Sie?'] =  object_columns['AP1. Wie alt sind Sie?'].replace(replacement_dict_Alter)

# %%
AP1_Series = object_columns['AP1. Wie alt sind Sie?']

# %%
object_columns.head()
# Out:
#    AP1. Wie alt sind Sie? AP9. Haben Sie ein Volontariat gemacht?   \
# 0                     2.0                                Sonstiges
# 1                     2.0                                Sonstiges
# 2                     4.0                                        1
# 3                     2.0                                        0
# 4                     2.0                                Sonstiges
#
#   AP12. Engagieren Sie sich ehrenamtlich im kunstwissenschaftlichen Bereich?   \
# 0                                                  0
# 1                                                  0
# 2                           Ja, in der Vergangenheit
# 3                                                  0
# 4                                                  1
#
# ...

# %%
object_columns.nunique()
# Out:
# AP1. Wie alt sind Sie?                                                                                                                                                                                                                                                                                                                                          11
# AP9. Haben Sie ein Volontariat gemacht?                                                                                                                                                                                                                                                                                                                          3
# ...

# %% [markdown]
# ### check out whether there are columns that can be one hot encoded

# %%
# Calculate number of unique values for each column
unique_counts = object_columns.nunique()

# Create a new DataFrame with the results
unique_counts_df = pd.DataFrame(unique_counts).reset_index()
unique_counts_df.columns = ['Column Name', 'Number of Unique Values']

unique_counts_df
# Out:
#                                           Column Name  Number of Unique Values
# 0                              AP1. Wie alt sind Sie?                       11
# 1            AP9. Haben Sie ein Volontariat gemacht?                         3
# 2   AP12. Engagieren Sie sich ehrenamtlich im kuns...                        3
# 3   AP14. Wir möchten im Folgenden gerne fragen, w...                        6
# 4   AS2. Wie lange sind bzw. waren Sie arbeitssuch...                        3
# ..                                                ...                      ...
# 87  UH23r. Was können Sie erst nach der Vertragsla...                        4
# 88  CO3r. Ist für andere wahrnehmbar, dass Sie ein...                        3
# 89        CO6. Welchem Geschlecht ordnen Sie sich zu?                        3
# 90  CO14. Wie sehen Sie die Rolle der AG Arbeitsbe...                      309
# 91  CO15. Haben Sie Anmerkungen oder Anregungen zu...                      193
#
# [92 rows x 2 columns]

# %%
unique_counts_df = unique_counts_df.sort_values(by='Number of Unique Values')

# %%
unique_counts_df
# Out:
#                                           Column Name  Number of Unique Values
# 10        F2. Arbeitszimmer, Büro oder Geschäftsraum:                        2
# 11       F3r. Wie ordnen Sie Ihre Nebentätigkeit ein?                        2
# 12  F6. Wie sichern Sie sich finanziell, rechtlich...                        2
# 63  S19r. Wenn ja, haben Sie die von Ihnen beantra...                        2
# 52  S3. Wie viele Stipendien (inklusive des derzei...                        2
# ..                                                ...                      ...
# 35  M3. Wie lautet die Bezeichnung für Ihre Tätigk...                       17
# 18  F17r. Aus folgenden Gründen (z.B. Verdienstaus...                       21
# 9   AS11r. In welchem Bereich arbeiten Sie bzw. we...                       25
# 91  CO15. Haben Sie Anmerkungen oder Anregungen zu...                      193
# 90  CO14. Wie sehen Sie die Rolle der AG Arbeitsbe...                      309
#
# [92 rows x 2 columns]

# %%
unique_counts_df.to_csv('/home/micha/Data_Science/Ulmer_Verein/Survey_working_conditions_art_history/data/interim/unique_values.csv')

# %%
object_columns['M1. In welcher Art Institution sind Sie tätig?'].unique()
# Out:
# array(['Museum bzw. Museumsverbund', nan, 'Sonstiges', 'Kunstsammlung',
#        'Kunstverein', 'Ausstellungshaus', 'Denkmalschutzbehörde',
#        'Stiftung bzw. Nachlass',
#        'Ausstellungsreihe (documenta, Biennalen)',
#        'Freundes- bzw. Förderkreis', 'Archiv'], dtype=object)

# %%
columns_to_encode = [col for col in object_columns.columns if object_columns[col].nunique() <= 17]

# One-hot encode these columns
one_hot_encoded_df = pd.get_dummies(object_columns, columns=columns_to_encode)

print(one_hot_encoded_df)
# Out:
#      AS11r. In welchem Bereich arbeiten Sie bzw. welche Tätigkeit üben Sie aus?  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1012                                                NaN
# 1013                                                NaN
# 1014                                                NaN
# 1015                                                NaN
# 1016                                                NaN
#
#      F17r. Aus folgenden Gründen (z.B. Verdienstausfall, Konflikt mit Auftraggeber:in):  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# ...

# %%
one_hot_encoded_df
# Out:
#      AS11r. In welchem Bereich arbeiten Sie bzw. welche Tätigkeit üben Sie aus?  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1012                                                NaN
# 1013                                                NaN
# 1014                                                NaN
# 1015                                                NaN
# 1016                                                NaN
#
#      F17r. Aus folgenden Gründen (z.B. Verdienstausfall, Konflikt mit Auftraggeber:in):  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# ...

# %%
#keep the age column as a single column as well
one_hot_encoded_df['AP1. Wie alt sind Sie?'] = AP1_Series

# %%
one_hot_encoded_df
# Out:
#      AS11r. In welchem Bereich arbeiten Sie bzw. welche Tätigkeit üben Sie aus?  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1012                                                NaN
# 1013                                                NaN
# 1014                                                NaN
# 1015                                                NaN
# 1016                                                NaN
#
#      F17r. Aus folgenden Gründen (z.B. Verdienstausfall, Konflikt mit Auftraggeber:in):  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# ...

# %% [markdown]
# ## check the numerical columns

# %%
numerical_columns = clean_data.select_dtypes(include='number')

# %%
numerical_columns
# Out:
#       id. Antwort ID  lastpage. Letzte Seite  seed. Zufallsgeneratorstartwert  \
# 0                953                       8                        396323143
# 1                 24                       8                        663729984
# 2                 57                       8                       1802233334
# 3                 65                       8                       1672017186
# 4                 93                       8                       1032237335
# ...              ...                     ...                              ...
# 1012            1726                       8                        439796185
# 1013            1727                       8                       1957822073
# 1014             913                       8                        998027907
# 1015            1732                       8                       1639414692
# 1016            1226                       8                       1765550616
#
# ...

# %%
numerical_columns = numerical_columns.drop(numerical_columns[['lastpage. Letzte Seite', 'seed. Zufallsgeneratorstartwert']], axis=1)

# %%
numerical_columns
# Out:
#       id. Antwort ID  \
# 0                953
# 1                 24
# 2                 57
# 3                 65
# 4                 93
# ...              ...
# 1012            1726
# 1013            1727
# 1014             913
# 1015            1732
# 1016            1226
#
#       AP2[SQ001]. Welchen akademischen Grad haben Sie als letztes in welchem Jahr erworben?    [Bachelor of Arts: ]  \
# 0                                                     0
# 1                                                     0
# 2                                                     0
# 3                                                     0
# 4                                                     0
# ...                                                 ...
# 1012                                                  0
# 1013                                                  1
# 1014                                                  0
# 1015                                                  0
# ...

# %% [markdown]
# ## concat the numeric columns and the one hot encoded columns

# %%
clean_data_df = pd.concat([numerical_columns, one_hot_encoded_df], axis=1)

# %%
clean_data_df.describe
# Out:
# <bound method NDFrame.describe of       id. Antwort ID  \
# 0                953
# 1                 24
# 2                 57
# 3                 65
# 4                 93
# ...              ...
# 1012            1726
# 1013            1727
# 1014             913
# 1015            1732
# 1016            1226
#
#       AP2[SQ001]. Welchen akademischen Grad haben Sie als letztes in welchem Jahr erworben?    [Bachelor of Arts: ]  \
# 0                                                     0
# 1                                                     0
# 2                                                     0
# 3                                                     0
# 4                                                     0
# ...                                                 ...
# 1012                                                  0
# 1013                                                  1
# 1014                                                  0
# ...

# %%
# sort the columns alphabetically
clean_data_df = clean_data_df.sort_index(axis=1)

# %%
clean_data_df.head()
# Out:
#    AP1. Wie alt sind Sie?  AP1. Wie alt sind Sie?_0.0  \
# 0                     2.0                       False
# 1                     2.0                       False
# 2                     4.0                       False
# 3                     2.0                       False
# 4                     2.0                       False
#
#    AP1. Wie alt sind Sie?_1.0  AP1. Wie alt sind Sie?_10.0  \
# 0                       False                        False
# 1                       False                        False
# 2                       False                        False
# 3                       False                        False
# 4                       False                        False
#
#    AP1. Wie alt sind Sie?_2.0  AP1. Wie alt sind Sie?_3.0  \
# 0                        True                       False
# 1                        True                       False
# 2                       False                       False
# ...

# %% [markdown]
# ### check the remaining object columns. Some of them might get deleted because of exhaustive NaN values

# %%
clean_data_df.select_dtypes(include='object').isna().sum()/len(clean_data_df)
# Out:
# AS11r. In welchem Bereich arbeiten Sie bzw. welche Tätigkeit üben Sie aus?                                                                                                               0.974435
# CO14. Wie sehen Sie die Rolle der AG Arbeitsbedingungen Kunstwissenschaft? Wie können wir Sie unterstützen? Was wünschen Sie sich von uns?                                               0.696165
# CO15. Haben Sie Anmerkungen oder Anregungen zu diesem Fragebogen und seinem Thema? Bitte schreiben Sie uns auch, wenn Sie eine Formulierung oder Frage als diskriminierend empfanden.    0.808260
# F17r. Aus folgenden Gründen (z.B. Verdienstausfall, Konflikt mit Auftraggeber:in):                                                                                                       0.963618
# dtype: float64

# %%
# select those participants that checked Arbeitssuchend in AP14
Arbeitssuchend_df = clean_data_df[clean_data_df['AP14. Wir möchten im Folgenden gerne fragen, wie genau die Arbeitsbedingungen und Beschäftigungsverhältnisse in den unterschiedlichen Berufsfeldern von Kunstwissenschaftler:innen gestaltet sind.\xa0  Wählen Sie bitte aus der folgenden Liste Ihr Haupttätigkeitsfeld bzw. Ihren derzeitigen Status – damit gelangen Sie zu den für Sie relevanten Fragen:\xa0_Arbeitssuchend bzw. ohne bezahlte kunstwissenschaftliche Arbeit']]
Arbeitssuchend_df.select_dtypes(include='object').isna().sum()/len(Arbeitssuchend_df)
# Out:
# AS11r. In welchem Bereich arbeiten Sie bzw. welche Tätigkeit üben Sie aus?                                                                                                               0.657895
# CO14. Wie sehen Sie die Rolle der AG Arbeitsbedingungen Kunstwissenschaft? Wie können wir Sie unterstützen? Was wünschen Sie sich von uns?                                               0.565789
# CO15. Haben Sie Anmerkungen oder Anregungen zu diesem Fragebogen und seinem Thema? Bitte schreiben Sie uns auch, wenn Sie eine Formulierung oder Frage als diskriminierend empfanden.    0.750000
# F17r. Aus folgenden Gründen (z.B. Verdienstausfall, Konflikt mit Auftraggeber:in):                                                                                                       1.000000
# dtype: float64

# %%
len(Arbeitssuchend_df)
# Out:
# 76

# %%
# select those participants that checked Arbeitssuchend in AP14
Freiberufler_df = clean_data_df[clean_data_df['AP14. Wir möchten im Folgenden gerne fragen, wie genau die Arbeitsbedingungen und Beschäftigungsverhältnisse in den unterschiedlichen Berufsfeldern von Kunstwissenschaftler:innen gestaltet sind.\xa0  Wählen Sie bitte aus der folgenden Liste Ihr Haupttätigkeitsfeld bzw. Ihren derzeitigen Status – damit gelangen Sie zu den für Sie relevanten Fragen:\xa0_Freiberufler:in']]
Freiberufler_df.select_dtypes(include='object').isna().sum()/len(Freiberufler_df)
# Out:
# AS11r. In welchem Bereich arbeiten Sie bzw. welche Tätigkeit üben Sie aus?                                                                                                               1.000000
# CO14. Wie sehen Sie die Rolle der AG Arbeitsbedingungen Kunstwissenschaft? Wie können wir Sie unterstützen? Was wünschen Sie sich von uns?                                               0.608333
# CO15. Haben Sie Anmerkungen oder Anregungen zu diesem Fragebogen und seinem Thema? Bitte schreiben Sie uns auch, wenn Sie eine Formulierung oder Frage als diskriminierend empfanden.    0.683333
# F17r. Aus folgenden Gründen (z.B. Verdienstausfall, Konflikt mit Auftraggeber:in):                                                                                                       0.691667
# dtype: float64

# %%
len(Freiberufler_df)
# Out:
# 120

# %% [markdown]
# CO14 and CO15 are questions that were presented to all participants. About 70% of all values are NaN and the rest of the values are diverse text entries. It is safe to remove them for the sake of numerical analysis.
# AS11r also shows a high proportion of NaN values (65%). It's safe to remove this column.
# F17r also shows a high proportion of NaN values (69%). It's safe to remove this column.

# %%
# remove all remaining object columns because they are safe to remove
clean_data_df = clean_data_df.drop(clean_data_df.select_dtypes(include='object'), axis=1)

# %%
clean_data_df
# Out:
#       AP1. Wie alt sind Sie?  AP1. Wie alt sind Sie?_0.0  \
# 0                        2.0                       False
# 1                        2.0                       False
# 2                        4.0                       False
# 3                        2.0                       False
# 4                        2.0                       False
# ...                      ...                         ...
# 1012                     3.0                       False
# 1013                     2.0                       False
# 1014                     5.0                       False
# 1015                     4.0                       False
# 1016                     4.0                       False
#
#       AP1. Wie alt sind Sie?_1.0  AP1. Wie alt sind Sie?_10.0  \
# 0                          False                        False
# 1                          False                        False
# 2                          False                        False
# ...

# %%
clean_data_df.to_csv('../data/interim/0_whole_dataset_wo_object_cols.csv', index=False)
